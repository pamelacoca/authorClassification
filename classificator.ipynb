# %%
import os
import nltk.tokenize as nt
import json
import torch
import copy
from torch import nn 
from torch.utils.data import Dataset, DataLoader

# %%
AUTHOR1 = "coutinho-dataset"
AUTHOR2 = "denser-dataset"
PATH_TO_RAW_DATA = "data/raw/"
PATH_TO_PARSED_DATA = "data/parsed/"

# %%
author1Path = os.path.join(PATH_TO_PARSED_DATA, AUTHOR1)
print(author1Path)
# Out:
# data/parsed/coutinho-dataset

# %%
author1AbsPath = os.path.abspath(author1Path)
author1Files = os.listdir(author1AbsPath)
print(len(author1Files))
# Out:
# 1614

# %%
def getParagraph(filename):
    f = open(filename, "r")
    paragraph = f.read()
    f.close()
    return paragraph

# %%
paragraphs = []
for filename in author1Files:
    paragraphs.append(getParagraph(author1AbsPath+"/"+filename))

print(paragraphs[0])
# Out:
#  O escritor (Jairo?) lembra que toda manha, por volta das   oito horas, um grupo de pessoas se reúne para rezar no Mirante, uma construção tipo quiosque, escondida entre as árvores de   uma elevação.

# %%
class Paragraph: 
    def __init__():
        self.original = []
        self.tokenized = []

# %%
dictAuthors = dict()

# %%
def mapToNumber(dict, word):
    if(word in dict.keys()):
        return dict.get(word)
    else:
        nextValue = len(dict.keys())+1
        dict.update({word: nextValue})
        return nextValue

# %%
def dictMapper(words, wordsmapped):
    for word in words:
        mapToNumber(wordsmapped, word)
    return wordsmapped

# %%
with open('authorsDict.json', 'w', encoding='utf-8') as f:
    json.dump(dictAuthors, f, ensure_ascii=False, indent=4)
f.close
# Out:
# <function TextIOWrapper.close()>

# %%
def tokenizeWordsInParagraph(paragraph, dict):
    tensor = []
    parsedParagraph = nt.word_tokenize(paragraph)
    for word in parsedParagraph:
        token = float(mapToNumber(dict, word))
        tensor.append(token)
    return tensor

# %%
def normalizeData(data, rule):
    while (len(data) < rule):
        data.append(0)

    if(len(data) > rule):
        data = data[0:rule]
    return data

# %%
def tokenizeParagraphSet(paragraphSet):
    tokenizedParagraphSet= []
    for paragraph in paragraphSet:
        tokenizedParagraph = tokenizeWordsInParagraph(paragraph, dictAuthors)
        tokenizedParagraph = normalizeData(tokenizedParagraph, 500)
        tokenizedParagraphSet.append(tokenizedParagraph)
    return tokenizedParagraphSet

# %%
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")

class NeuralNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(500, 850),
            nn.Sigmoid(),
            nn.Linear(850, 500),
            nn.Sigmoid(),
            nn.Linear(500, 2),
        )

    def forward(self, x):
        logits = self.linear_relu_stack(x)
        return logits

model = NeuralNetwork().to(device)
print(model)
# Out:
# Using mps device
# NeuralNetwork(
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=500, out_features=850, bias=True)
#     (1): Sigmoid()
#     (2): Linear(in_features=850, out_features=500, bias=True)
#     (3): Sigmoid()
#     (4): Linear(in_features=500, out_features=2, bias=True)
#   )
# )

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=1e-3)

# %%
def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    model.train()
    for batch, (X,y) in enumerate(dataloader):
        #print(batch)
        X, y = X.to(device), y.to(device)

        # Compute prediction error
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

        if batch % 100 == 0:
            loss, current = loss.item(), (batch + 1) * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")

# %%
def test(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0, 0
    with torch.no_grad():
        for X,y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    test_loss /= num_batches
    correct /= size
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")
    return correct

# %%
def recoverStoredData(AUTHOR, nFiles):

    print(os.path.exists(PATH_TO_PARSED_DATA))

    PATH_AUTHOR_PARSED_DATA = os.path.join(PATH_TO_PARSED_DATA,AUTHOR)

    selectedParagraphs = []

    for i in range(0,nFiles):
        nf = open(os.path.join(PATH_AUTHOR_PARSED_DATA,AUTHOR)+"_"+str(i)+".txt","r")
        selectedParagraphs.append(nf.read())
        nf.close()
    
    return selectedParagraphs

# %%
author1ParagraphSet = recoverStoredData(AUTHOR1, 1614)
author2ParagraphSet = recoverStoredData(AUTHOR2, 1614)
# Out:
# True
# True

# %%
author1TokenizedParagraphSet = tokenizeParagraphSet(author1ParagraphSet)
author2TokenizedParagraphSet = tokenizeParagraphSet(author2ParagraphSet)

# %%
class CustomTextDataset(Dataset):
    def __init__(self, txt, labels):
        self.labels = labels
        self.text = txt
    def __len__(self):
        return len(self.labels)
    def __getitem__(self, idx):
        label = self.labels[idx]
        text = self.text[idx]
        sample = [text, label]
        return sample

# %%
input_training_data = author1TokenizedParagraphSet[0:400]
input_test_data = author1TokenizedParagraphSet[400:500]

input_training_data.extend(author2TokenizedParagraphSet[0:400])
input_test_data.extend(author2TokenizedParagraphSet[400:500])

input_training_data = torch.tensor(input_training_data)
input_test_data = torch.tensor(input_test_data)

input_training_label = [0]*400
input_training_label.extend([1]*400)

input_test_label = [0]*100
input_test_label.extend([1]*100)

# %%
input_training_dataset = CustomTextDataset(input_training_data, input_training_label)
input_test_dataset = CustomTextDataset(input_test_data, input_test_label)

# %%
train_dataloader = DataLoader(input_training_dataset, batch_size=8, shuffle=True)
test_dataloader = DataLoader(input_test_dataset, batch_size=8, shuffle=True)

# %%
epochs = 120
max_accurracy = 0.0
best_model = ""
for te in range(epochs):
    print(f"Epoch {te+1}\n-------------------------------")
    train(train_dataloader, model, loss_fn, optimizer)
    accurracy = test(test_dataloader, model, loss_fn)
    if(accurracy > max_accurracy):
        max_accurracy = accurracy
        best_model = copy.deepcopy(model)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 0.656779  [    8/  800]
# Test Error:
#  Accuracy: 63.0%, Avg loss: 0.681870
#
# Epoch 2
# -------------------------------
# loss: 0.676642  [    8/  800]
# Test Error:
#  Accuracy: 66.0%, Avg loss: 0.673246
#
# Epoch 3
# -------------------------------
# loss: 0.660870  [    8/  800]
# Test Error:
#  Accuracy: 54.5%, Avg loss: 0.667238
#
# Epoch 4
# -------------------------------
# loss: 0.613319  [    8/  800]
# Test Error:
#  Accuracy: 70.0%, Avg loss: 0.658878
#
# Epoch 5
# -------------------------------
# loss: 0.641638  [    8/  800]
# Test Error:
#  Accuracy: 69.0%, Avg loss: 0.651110
#
# Epoch 6
# -------------------------------
# loss: 0.649743  [    8/  800]
# Test Error:
#  Accuracy: 60.5%, Avg loss: 0.647891
#
# Epoch 7
# -------------------------------
# loss: 0.629200  [    8/  800]
# Test Error:
#  Accuracy: 51.5%, Avg loss: 0.643310
#
# Epoch 8
# -------------------------------
# loss: 0.647700  [    8/  800]
# Test Error:
#  Accuracy: 82.0%, Avg loss: 0.629291
#
# Epoch 9
# -------------------------------
# loss: 0.614350  [    8/  800]
# Test Error:
#  Accuracy: 76.0%, Avg loss: 0.624773
#
# Epoch 10
# -------------------------------
# loss: 0.682854  [    8/  800]
# Test Error:
#  Accuracy: 86.0%, Avg loss: 0.613061
#
# Epoch 11
# -------------------------------
# loss: 0.635232  [    8/  800]
# Test Error:
#  Accuracy: 86.0%, Avg loss: 0.605871
#
# Epoch 12
# -------------------------------
# loss: 0.603163  [    8/  800]
# Test Error:
#  Accuracy: 86.0%, Avg loss: 0.597811
#
# Epoch 13
# -------------------------------
# loss: 0.583879  [    8/  800]
# Test Error:
#  Accuracy: 87.0%, Avg loss: 0.590582
#
# Epoch 14
# -------------------------------
# loss: 0.601037  [    8/  800]
# Test Error:
#  Accuracy: 87.0%, Avg loss: 0.582073
#
# Epoch 15
# -------------------------------
# loss: 0.577311  [    8/  800]
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.575791
#
# Epoch 16
# -------------------------------
# loss: 0.585739  [    8/  800]
# Test Error:
#  Accuracy: 87.5%, Avg loss: 0.568401
#
# Epoch 17
# -------------------------------
# loss: 0.632178  [    8/  800]
# Test Error:
#  Accuracy: 84.0%, Avg loss: 0.563109
#
# Epoch 18
# -------------------------------
# loss: 0.482887  [    8/  800]
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.548055
#
# Epoch 19
# -------------------------------
# loss: 0.509627  [    8/  800]
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.543988
#
# Epoch 20
# -------------------------------
# loss: 0.507826  [    8/  800]
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.535333
#
# Epoch 21
# -------------------------------
# loss: 0.509710  [    8/  800]
# Test Error:
#  Accuracy: 87.5%, Avg loss: 0.521642
#
# Epoch 22
# -------------------------------
# loss: 0.535875  [    8/  800]
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.521681
#
# Epoch 23
# -------------------------------
# loss: 0.544570  [    8/  800]
# Test Error:
#  Accuracy: 89.0%, Avg loss: 0.506007
#
# Epoch 24
# -------------------------------
# loss: 0.458759  [    8/  800]
# Test Error:
#  Accuracy: 88.5%, Avg loss: 0.498948
#
# Epoch 25
# -------------------------------
# loss: 0.522688  [    8/  800]
# Test Error:
#  Accuracy: 90.0%, Avg loss: 0.489313
#
# Epoch 26
# -------------------------------
# loss: 0.417008  [    8/  800]
# Test Error:
#  Accuracy: 87.5%, Avg loss: 0.481321
#
# Epoch 27
# -------------------------------
# loss: 0.532357  [    8/  800]
# Test Error:
#  Accuracy: 90.0%, Avg loss: 0.474213
#
# Epoch 28
# -------------------------------
# loss: 0.405224  [    8/  800]
# Test Error:
#  Accuracy: 87.0%, Avg loss: 0.465429
#
# Epoch 29
# -------------------------------
# loss: 0.493985  [    8/  800]
# Test Error:
#  Accuracy: 89.5%, Avg loss: 0.458801
#
# Epoch 30
# -------------------------------
# loss: 0.572670  [    8/  800]
# Test Error:
#  Accuracy: 89.5%, Avg loss: 0.453288
#
# Epoch 31
# -------------------------------
# loss: 0.499952  [    8/  800]
# Test Error:
#  Accuracy: 89.5%, Avg loss: 0.444258
#
# Epoch 32
# -------------------------------
# loss: 0.437999  [    8/  800]
# Test Error:
#  Accuracy: 89.5%, Avg loss: 0.442780
#
# Epoch 33
# -------------------------------
# loss: 0.381758  [    8/  800]
# Test Error:
#  Accuracy: 89.0%, Avg loss: 0.430539
#
# Epoch 34
# -------------------------------
# loss: 0.570606  [    8/  800]
# Test Error:
#  Accuracy: 90.5%, Avg loss: 0.424222
#
# Epoch 35
# -------------------------------
# loss: 0.601398  [    8/  800]
# Test Error:
#  Accuracy: 91.5%, Avg loss: 0.416089
#
# Epoch 36
# -------------------------------
# loss: 0.269475  [    8/  800]
# Test Error:
#  Accuracy: 91.0%, Avg loss: 0.411507
#
# Epoch 37
# -------------------------------
# loss: 0.242044  [    8/  800]
# Test Error:
#  Accuracy: 89.5%, Avg loss: 0.409820
#
# Epoch 38
# -------------------------------
# loss: 0.339668  [    8/  800]
# Test Error:
#  Accuracy: 91.0%, Avg loss: 0.400889
#
# Epoch 39
# -------------------------------
# loss: 0.334594  [    8/  800]
# Test Error:
#  Accuracy: 91.0%, Avg loss: 0.395250
#
# Epoch 40
# -------------------------------
# loss: 0.364351  [    8/  800]
# Test Error:
#  Accuracy: 91.0%, Avg loss: 0.391688
#
# Epoch 41
# -------------------------------
# loss: 0.360754  [    8/  800]
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.382972
#
# Epoch 42
# -------------------------------
# loss: 0.359216  [    8/  800]
# Test Error:
#  Accuracy: 91.5%, Avg loss: 0.377886
#
# Epoch 43
# -------------------------------
# loss: 0.302292  [    8/  800]
# Test Error:
#  Accuracy: 91.0%, Avg loss: 0.374002
#
# Epoch 44
# -------------------------------
# loss: 0.300487  [    8/  800]
# Test Error:
#  Accuracy: 91.5%, Avg loss: 0.370599
#
# Epoch 45
# -------------------------------
# loss: 0.301041  [    8/  800]
# Test Error:
#  Accuracy: 91.5%, Avg loss: 0.364970
#
# Epoch 46
# -------------------------------
# loss: 0.273733  [    8/  800]
# Test Error:
#  Accuracy: 92.0%, Avg loss: 0.357289
#
# Epoch 47
# -------------------------------
# loss: 0.232436  [    8/  800]
# Test Error:
#  Accuracy: 89.0%, Avg loss: 0.362379
#
# Epoch 48
# -------------------------------
# loss: 0.359791  [    8/  800]
# Test Error:
#  Accuracy: 92.0%, Avg loss: 0.354381
#
# Epoch 49
# -------------------------------
# loss: 0.258412  [    8/  800]
# Test Error:
#  Accuracy: 92.0%, Avg loss: 0.351470
#
# Epoch 50
# -------------------------------
# loss: 0.282324  [    8/  800]
# Test Error:
#  Accuracy: 91.5%, Avg loss: 0.349576
#
# Epoch 51
# -------------------------------
# loss: 0.285240  [    8/  800]
# Test Error:
#  Accuracy: 91.0%, Avg loss: 0.345309
#
# Epoch 52
# -------------------------------
# loss: 0.181706  [    8/  800]
# Test Error:
#  Accuracy: 91.5%, Avg loss: 0.341813
#
# Epoch 53
# -------------------------------
# loss: 0.310387  [    8/  800]
# Test Error:
#  Accuracy: 91.5%, Avg loss: 0.339895
#
# Epoch 54
# -------------------------------
# loss: 0.238495  [    8/  800]
# Test Error:
#  Accuracy: 89.5%, Avg loss: 0.340817
#
# Epoch 55
# -------------------------------
# loss: 0.329792  [    8/  800]
# Test Error:
#  Accuracy: 90.5%, Avg loss: 0.333246
#
# Epoch 56
# -------------------------------
# loss: 0.321527  [    8/  800]
# Test Error:
#  Accuracy: 92.0%, Avg loss: 0.327106
#
# Epoch 57
# -------------------------------
# loss: 0.214763  [    8/  800]
# Test Error:
#  Accuracy: 91.0%, Avg loss: 0.328561
#
# Epoch 58
# -------------------------------
# loss: 0.404085  [    8/  800]
# Test Error:
#  Accuracy: 91.0%, Avg loss: 0.323996
#
# Epoch 59
# -------------------------------
# loss: 0.350225  [    8/  800]
# Test Error:
#  Accuracy: 90.0%, Avg loss: 0.326409
#
# Epoch 60
# -------------------------------
# loss: 0.253828  [    8/  800]
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.314759
#
# Epoch 61
# -------------------------------
# loss: 0.195996  [    8/  800]
# Test Error:
#  Accuracy: 90.0%, Avg loss: 0.315285
#
# Epoch 62
# -------------------------------
# loss: 0.215739  [    8/  800]
# Test Error:
#  Accuracy: 91.5%, Avg loss: 0.314715
#
# Epoch 63
# -------------------------------
# loss: 0.285543  [    8/  800]
# Test Error:
#  Accuracy: 91.5%, Avg loss: 0.308452
#
# Epoch 64
# -------------------------------
# loss: 0.451479  [    8/  800]
# Test Error:
#  Accuracy: 91.5%, Avg loss: 0.305469
#
# Epoch 65
# -------------------------------
# loss: 0.331277  [    8/  800]
# Test Error:
#  Accuracy: 90.0%, Avg loss: 0.310646
#
# Epoch 66
# -------------------------------
# loss: 0.160241  [    8/  800]
# Test Error:
#  Accuracy: 91.5%, Avg loss: 0.303993
#
# Epoch 67
# -------------------------------
# loss: 0.367253  [    8/  800]
# Test Error:
#  Accuracy: 92.0%, Avg loss: 0.311644
#
# Epoch 68
# -------------------------------
# loss: 0.130419  [    8/  800]
# Test Error:
#  Accuracy: 91.5%, Avg loss: 0.309560
#
# Epoch 69
# -------------------------------
# loss: 0.097939  [    8/  800]
# Test Error:
#  Accuracy: 91.0%, Avg loss: 0.296824
#
# Epoch 70
# -------------------------------
# loss: 0.359725  [    8/  800]
# Test Error:
#  Accuracy: 92.0%, Avg loss: 0.298556
#
# Epoch 71
# -------------------------------
# loss: 0.159606  [    8/  800]
# Test Error:
#  Accuracy: 92.0%, Avg loss: 0.295396
#
# Epoch 72
# -------------------------------
# loss: 0.291514  [    8/  800]
# Test Error:
#  Accuracy: 91.5%, Avg loss: 0.297805
#
# Epoch 73
# -------------------------------
# loss: 0.202682  [    8/  800]
# Test Error:
#  Accuracy: 93.0%, Avg loss: 0.287808
#
# Epoch 74
# -------------------------------
# loss: 0.273523  [    8/  800]
# Test Error:
#  Accuracy: 91.5%, Avg loss: 0.288591
#
# Epoch 75
# -------------------------------
# loss: 0.145104  [    8/  800]
# Test Error:
#  Accuracy: 92.0%, Avg loss: 0.285963
#
# Epoch 76
# -------------------------------
# loss: 0.280725  [    8/  800]
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.287183
#
# Epoch 77
# -------------------------------
# loss: 0.119594  [    8/  800]
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.281376
#
# Epoch 78
# -------------------------------
# loss: 0.093038  [    8/  800]
# Test Error:
#  Accuracy: 94.0%, Avg loss: 0.278546
#
# Epoch 79
# -------------------------------
# loss: 0.107785  [    8/  800]
# Test Error:
#  Accuracy: 93.0%, Avg loss: 0.281284
#
# Epoch 80
# -------------------------------
# loss: 0.066752  [    8/  800]
# Test Error:
#  Accuracy: 92.0%, Avg loss: 0.281912
#
# Epoch 81
# -------------------------------
# loss: 0.292620  [    8/  800]
# Test Error:
#  Accuracy: 93.5%, Avg loss: 0.275463
#
# Epoch 82
# -------------------------------
# loss: 0.451708  [    8/  800]
# Test Error:
#  Accuracy: 91.5%, Avg loss: 0.286166
#
# Epoch 83
# -------------------------------
# loss: 0.482143  [    8/  800]
# Test Error:
#  Accuracy: 92.0%, Avg loss: 0.284570
#
# Epoch 84
# -------------------------------
# loss: 0.123789  [    8/  800]
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.272936
#
# Epoch 85
# -------------------------------
# loss: 0.254743  [    8/  800]
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.276734
#
# Epoch 86
# -------------------------------
# loss: 0.194403  [    8/  800]
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.277852
#
# Epoch 87
# -------------------------------
# loss: 0.153265  [    8/  800]
# Test Error:
#  Accuracy: 93.5%, Avg loss: 0.267633
#
# Epoch 88
# -------------------------------
# loss: 0.257482  [    8/  800]
# Test Error:
#  Accuracy: 93.5%, Avg loss: 0.270879
#
# Epoch 89
# -------------------------------
# loss: 0.313245  [    8/  800]
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.272069
#
# Epoch 90
# -------------------------------
# loss: 0.283963  [    8/  800]
# Test Error:
#  Accuracy: 93.0%, Avg loss: 0.267937
#
# Epoch 91
# -------------------------------
# loss: 0.228151  [    8/  800]
# Test Error:
#  Accuracy: 94.0%, Avg loss: 0.263283
#
# Epoch 92
# -------------------------------
# loss: 0.181712  [    8/  800]
# Test Error:
#  Accuracy: 94.0%, Avg loss: 0.259603
#
# Epoch 93
# -------------------------------
# loss: 0.110967  [    8/  800]
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.268762
#
# Epoch 94
# -------------------------------
# loss: 0.101709  [    8/  800]
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.265265
#
# Epoch 95
# -------------------------------
# loss: 0.250204  [    8/  800]
# Test Error:
#  Accuracy: 93.0%, Avg loss: 0.263396
#
# Epoch 96
# -------------------------------
# loss: 0.398768  [    8/  800]
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.262704
#
# Epoch 97
# -------------------------------
# loss: 0.291466  [    8/  800]
# Test Error:
#  Accuracy: 93.0%, Avg loss: 0.257334
#
# Epoch 98
# -------------------------------
# loss: 0.124075  [    8/  800]
# Test Error:
#  Accuracy: 93.0%, Avg loss: 0.252785
#
# Epoch 99
# -------------------------------
# loss: 0.141233  [    8/  800]
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.254438
#
# Epoch 100
# -------------------------------
# loss: 0.086783  [    8/  800]
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.255421
#
# Epoch 101
# -------------------------------
# loss: 0.245918  [    8/  800]
# Test Error:
#  Accuracy: 94.5%, Avg loss: 0.248033
#
# Epoch 102
# -------------------------------
# loss: 0.060459  [    8/  800]
# Test Error:
#  Accuracy: 94.0%, Avg loss: 0.243154
#
# Epoch 103
# -------------------------------
# loss: 0.125070  [    8/  800]
# Test Error:
#  Accuracy: 93.5%, Avg loss: 0.248298
#
# Epoch 104
# -------------------------------
# loss: 0.068843  [    8/  800]
# Test Error:
#  Accuracy: 93.0%, Avg loss: 0.246609
#
# Epoch 105
# -------------------------------
# loss: 0.208331  [    8/  800]
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.253001
#
# Epoch 106
# -------------------------------
# loss: 0.064469  [    8/  800]
# Test Error:
#  Accuracy: 93.5%, Avg loss: 0.244849
#
# Epoch 107
# -------------------------------
# loss: 0.119040  [    8/  800]
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.243276
#
# Epoch 108
# -------------------------------
# loss: 0.212301  [    8/  800]
# Test Error:
#  Accuracy: 93.5%, Avg loss: 0.246686
#
# Epoch 109
# -------------------------------
# loss: 0.549421  [    8/  800]
# Test Error:
#  Accuracy: 93.0%, Avg loss: 0.241405
#
# Epoch 110
# -------------------------------
# loss: 0.236308  [    8/  800]
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.249038
#
# Epoch 111
# -------------------------------
# loss: 0.039809  [    8/  800]
# Test Error:
#  Accuracy: 93.0%, Avg loss: 0.241766
#
# Epoch 112
# -------------------------------
# loss: 0.118098  [    8/  800]
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.244258
#
# Epoch 113
# -------------------------------
# loss: 0.304487  [    8/  800]
# Test Error:
#  Accuracy: 93.0%, Avg loss: 0.242505
#
# Epoch 114
# -------------------------------
# loss: 0.261541  [    8/  800]
# Test Error:
#  Accuracy: 93.5%, Avg loss: 0.237788
#
# Epoch 115
# -------------------------------
# loss: 0.239553  [    8/  800]
# Test Error:
#  Accuracy: 93.0%, Avg loss: 0.239813
#
# Epoch 116
# -------------------------------
# loss: 0.199790  [    8/  800]
# Test Error:
#  Accuracy: 93.0%, Avg loss: 0.239958
#
# Epoch 117
# -------------------------------
# loss: 0.080859  [    8/  800]
# Test Error:
#  Accuracy: 93.5%, Avg loss: 0.239739
#
# Epoch 118
# -------------------------------
# loss: 0.157338  [    8/  800]
# Test Error:
#  Accuracy: 94.0%, Avg loss: 0.233680
#
# Epoch 119
# -------------------------------
# loss: 0.283913  [    8/  800]
# Test Error:
#  Accuracy: 95.0%, Avg loss: 0.230188
#
# Epoch 120
# -------------------------------
# loss: 0.089631  [    8/  800]
# Test Error:
#  Accuracy: 94.0%, Avg loss: 0.236901
#
# Done!

# %%
pos = 12
model.eval()
x, y = input_test_dataset[pos][0], input_test_dataset[pos][1]

print("accurracy: ",max_accurracy*100,"%")

#print(x,y)
with torch.no_grad():
    x = x.to(device)
    pred = best_model(x)
    print(pred)
    predicted, actual = pred.argmax(0), y
    print(f'Predicted: "{predicted}", Actual: "{actual}"')
# Out:
# accurracy:  95.0 %
# tensor([ 1.1579, -1.6482], device='mps:0')
# Predicted: "0", Actual: "0"

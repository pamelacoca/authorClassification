# %%
import time
import os
import nltk.tokenize as nt
import json
import torch
import copy
from torch import nn 
from torch.utils.data import Dataset, DataLoader

# %%
AUTHOR1 = "coutinho-dataset"
AUTHOR2 = "denser-dataset"
PATH_TO_RAW_DATA = "data/raw/"
PATH_TO_PARSED_DATA = "data/parsed/"

# %%
author1Path = os.path.join(PATH_TO_PARSED_DATA, AUTHOR1)
print(author1Path)
# Out:
# data/parsed/coutinho-dataset

# %%
author1AbsPath = os.path.abspath(author1Path)
author1Files = os.listdir(author1AbsPath)
print(len(author1Files))
# Out:
# 1614

# %%
def getParagraph(filename):
    f = open(filename, "r")
    paragraph = f.read()
    f.close()
    return paragraph

# %%
paragraphs = []
for filename in author1Files:
    paragraphs.append(getParagraph(author1AbsPath+"/"+filename))

print(paragraphs[0])
# Out:
#  O escritor (Jairo?) lembra que toda manha, por volta das   oito horas, um grupo de pessoas se reúne para rezar no Mirante, uma construção tipo quiosque, escondida entre as árvores de   uma elevação.

# %%
class Paragraph: 
    def __init__():
        self.original = []
        self.tokenized = []

# %%
dictAuthors = dict()

# %%
def mapToNumber(dict, word):
    if(word in dict.keys()):
        return dict.get(word)
    else:
        nextValue = len(dict.keys())+1
        dict.update({word: nextValue})
        return nextValue

# %%
def dictMapper(words, wordsmapped):
    for word in words:
        mapToNumber(wordsmapped, word)
    return wordsmapped

# %%
with open('authorsDict.json', 'w', encoding='utf-8') as f:
    json.dump(dictAuthors, f, ensure_ascii=False, indent=4)
f.close
# Out:
# <function TextIOWrapper.close()>

# %%
def tokenizeWordsInParagraph(paragraph, dict):
    tensor = []
    parsedParagraph = nt.word_tokenize(paragraph)
    for word in parsedParagraph:
        token = float(mapToNumber(dict, word))
        tensor.append(token)
    return tensor

# %%
def normalizeData(data, rule):
    while (len(data) < rule):
        data.append(0)

    if(len(data) > rule):
        data = data[0:rule]
    return data

# %%
def tokenizeParagraphSet(paragraphSet):
    tokenizedParagraphSet= []
    for paragraph in paragraphSet:
        tokenizedParagraph = tokenizeWordsInParagraph(paragraph, dictAuthors)
        tokenizedParagraph = normalizeData(tokenizedParagraph, 500)
        tokenizedParagraphSet.append(tokenizedParagraph)
    return tokenizedParagraphSet

# %%
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")

class NeuralNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(500, 850),
            nn.Sigmoid(),
            nn.Linear(850, 500),
            nn.Sigmoid(),
            nn.Linear(500, 2),
        )

    def forward(self, x):
        logits = self.linear_relu_stack(x)
        return logits

model = NeuralNetwork().to(device)
print(model)
# Out:
# Using mps device
# NeuralNetwork(
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=500, out_features=850, bias=True)
#     (1): Sigmoid()
#     (2): Linear(in_features=850, out_features=500, bias=True)
#     (3): Sigmoid()
#     (4): Linear(in_features=500, out_features=2, bias=True)
#   )
# )

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=1e-3)

# %%
def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    model.train()
    for batch, (X,y) in enumerate(dataloader):
        #print(batch)
        X, y = X.to(device), y.to(device)

        # Compute prediction error
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

        if batch % 100 == 0:
            loss, current = loss.item(), (batch + 1) * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")

# %%
def test(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0, 0
    with torch.no_grad():
        for X,y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    test_loss /= num_batches
    correct /= size
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")
    return correct

# %%
def recoverStoredData(AUTHOR, nFiles):

    print(os.path.exists(PATH_TO_PARSED_DATA))

    PATH_AUTHOR_PARSED_DATA = os.path.join(PATH_TO_PARSED_DATA,AUTHOR)

    selectedParagraphs = []

    for i in range(0,nFiles):
        nf = open(os.path.join(PATH_AUTHOR_PARSED_DATA,AUTHOR)+"_"+str(i)+".txt","r")
        selectedParagraphs.append(nf.read())
        nf.close()
    
    return selectedParagraphs

# %%
author1ParagraphSet = recoverStoredData(AUTHOR1, 1614)
author2ParagraphSet = recoverStoredData(AUTHOR2, 1614)
# Out:
# True
# True

# %%
author1TokenizedParagraphSet = tokenizeParagraphSet(author1ParagraphSet)
author2TokenizedParagraphSet = tokenizeParagraphSet(author2ParagraphSet)

# %%
class CustomTextDataset(Dataset):
    def __init__(self, txt, labels):
        self.labels = labels
        self.text = txt
    def __len__(self):
        return len(self.labels)
    def __getitem__(self, idx):
        label = self.labels[idx]
        text = self.text[idx]
        sample = [text, label]
        return sample

# %%
input_training_data = author1TokenizedParagraphSet[0:400]
input_test_data = author1TokenizedParagraphSet[400:500]

input_training_data.extend(author2TokenizedParagraphSet[0:400])
input_test_data.extend(author2TokenizedParagraphSet[400:500])

input_training_data = torch.tensor(input_training_data)
input_test_data = torch.tensor(input_test_data)

input_training_label = [0]*400
input_training_label.extend([1]*400)

input_test_label = [0]*100
input_test_label.extend([1]*100)

# %%
input_training_dataset = CustomTextDataset(input_training_data, input_training_label)
input_test_dataset = CustomTextDataset(input_test_data, input_test_label)

# %%
train_dataloader = DataLoader(input_training_dataset, batch_size=8, shuffle=True)
test_dataloader = DataLoader(input_test_dataset, batch_size=8, shuffle=True)

# %%
epochs = 120
max_accurracy = 0.0
best_model = ""
training_start_time = time.time()
for te in range(epochs):
    print(f"Epoch {te+1}\n-------------------------------")
    train(train_dataloader, model, loss_fn, optimizer)
    accurracy = test(test_dataloader, model, loss_fn)
    if(accurracy > max_accurracy):
        max_accurracy = accurracy
        best_model = copy.deepcopy(model)
print("Done!")
print('Training finished, took {:.2f}s'.format(time.time() - training_start_time))
# Out:
# Epoch 1
# -------------------------------
# loss: 0.036634  [    8/  800]
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.131339
#
# Epoch 2
# -------------------------------
# loss: 0.119908  [    8/  800]
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.129845
#
# Epoch 3
# -------------------------------
# loss: 0.004537  [    8/  800]
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.131962
#
# Epoch 4
# -------------------------------
# loss: 0.007061  [    8/  800]
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.131360
#
# Epoch 5
# -------------------------------
# loss: 0.006822  [    8/  800]
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.131592
#
# Epoch 6
# -------------------------------
# loss: 0.050853  [    8/  800]
# Test Error:
#  Accuracy: 95.5%, Avg loss: 0.132429
#
# Epoch 7
# -------------------------------
# loss: 0.012260  [    8/  800]
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.131992
#
# Epoch 8
# -------------------------------
# loss: 0.020661  [    8/  800]
# Test Error:
#  Accuracy: 95.5%, Avg loss: 0.132637
#
# Epoch 9
# -------------------------------
# loss: 0.049531  [    8/  800]
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.131644
#
# Epoch 10
# -------------------------------
# loss: 0.003993  [    8/  800]
# Test Error:
#  Accuracy: 95.5%, Avg loss: 0.132303
#
# Epoch 11
# -------------------------------
# loss: 0.023581  [    8/  800]
# Test Error:
#  Accuracy: 95.5%, Avg loss: 0.133783
#
# Epoch 12
# -------------------------------
# loss: 0.008968  [    8/  800]
# Test Error:
#  Accuracy: 95.5%, Avg loss: 0.132412
#
# Epoch 13
# -------------------------------
# loss: 0.008847  [    8/  800]
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.130006
#
# Epoch 14
# -------------------------------
# loss: 0.121139  [    8/  800]
# Test Error:
#  Accuracy: 95.5%, Avg loss: 0.131534
#
# Epoch 15
# -------------------------------
# loss: 0.033037  [    8/  800]
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.130614
#
# Epoch 16
# -------------------------------
# loss: 0.011449  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.130062
#
# Epoch 17
# -------------------------------
# loss: 0.005108  [    8/  800]
# Test Error:
#  Accuracy: 95.5%, Avg loss: 0.131208
#
# Epoch 18
# -------------------------------
# loss: 0.009798  [    8/  800]
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.129169
#
# Epoch 19
# -------------------------------
# loss: 0.012090  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.127456
#
# Epoch 20
# -------------------------------
# loss: 0.009018  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.126797
#
# Epoch 21
# -------------------------------
# loss: 0.006245  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.126973
#
# Epoch 22
# -------------------------------
# loss: 0.035945  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.127286
#
# Epoch 23
# -------------------------------
# loss: 0.094651  [    8/  800]
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.129759
#
# Epoch 24
# -------------------------------
# loss: 0.010245  [    8/  800]
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.129757
#
# Epoch 25
# -------------------------------
# loss: 0.042388  [    8/  800]
# Test Error:
#  Accuracy: 95.5%, Avg loss: 0.129909
#
# Epoch 26
# -------------------------------
# loss: 0.015776  [    8/  800]
# Test Error:
#  Accuracy: 95.5%, Avg loss: 0.129961
#
# Epoch 27
# -------------------------------
# loss: 0.005390  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.127895
#
# Epoch 28
# -------------------------------
# loss: 0.021176  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.128339
#
# Epoch 29
# -------------------------------
# loss: 0.012061  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.127789
#
# Epoch 30
# -------------------------------
# loss: 0.916610  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.128158
#
# Epoch 31
# -------------------------------
# loss: 0.002989  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.129417
#
# Epoch 32
# -------------------------------
# loss: 0.013924  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.128470
#
# Epoch 33
# -------------------------------
# loss: 0.021216  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.127941
#
# Epoch 34
# -------------------------------
# loss: 0.142091  [    8/  800]
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.131439
#
# Epoch 35
# -------------------------------
# loss: 0.008086  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.130632
#
# Epoch 36
# -------------------------------
# loss: 0.130180  [    8/  800]
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.131698
#
# Epoch 37
# -------------------------------
# loss: 0.092538  [    8/  800]
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.131399
#
# Epoch 38
# -------------------------------
# loss: 0.008394  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.129039
#
# Epoch 39
# -------------------------------
# loss: 0.074143  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.127960
#
# Epoch 40
# -------------------------------
# loss: 0.002700  [    8/  800]
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.130495
#
# Epoch 41
# -------------------------------
# loss: 0.086707  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.127895
#
# Epoch 42
# -------------------------------
# loss: 0.006064  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.129155
#
# Epoch 43
# -------------------------------
# loss: 0.005844  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.129779
#
# Epoch 44
# -------------------------------
# loss: 0.023715  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.127971
#
# Epoch 45
# -------------------------------
# loss: 0.008232  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.128236
#
# Epoch 46
# -------------------------------
# loss: 0.002688  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.129206
#
# Epoch 47
# -------------------------------
# loss: 0.009411  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.127352
#
# Epoch 48
# -------------------------------
# loss: 0.077524  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.128592
#
# Epoch 49
# -------------------------------
# loss: 0.056695  [    8/  800]
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.131250
#
# Epoch 50
# -------------------------------
# loss: 0.016409  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.129210
#
# Epoch 51
# -------------------------------
# loss: 0.021709  [    8/  800]
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.130639
#
# Epoch 52
# -------------------------------
# loss: 0.007026  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.128125
#
# Epoch 53
# -------------------------------
# loss: 0.007104  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.127183
#
# Epoch 54
# -------------------------------
# loss: 0.024541  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.129103
#
# Epoch 55
# -------------------------------
# loss: 0.020259  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.128471
#
# Epoch 56
# -------------------------------
# loss: 0.022218  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.129375
#
# Epoch 57
# -------------------------------
# loss: 0.027588  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.128743
#
# Epoch 58
# -------------------------------
# loss: 0.002080  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.127341
#
# Epoch 59
# -------------------------------
# loss: 0.017022  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.129352
#
# Epoch 60
# -------------------------------
# loss: 0.873902  [    8/  800]
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.129896
#
# Epoch 61
# -------------------------------
# loss: 0.008006  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.128332
#
# Epoch 62
# -------------------------------
# loss: 0.013425  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.127463
#
# Epoch 63
# -------------------------------
# loss: 0.003246  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.127907
#
# Epoch 64
# -------------------------------
# loss: 0.006303  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.127961
#
# Epoch 65
# -------------------------------
# loss: 0.011548  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.126638
#
# Epoch 66
# -------------------------------
# loss: 0.186331  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.128194
#
# Epoch 67
# -------------------------------
# loss: 0.030944  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.128222
#
# Epoch 68
# -------------------------------
# loss: 0.006246  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.127574
#
# Epoch 69
# -------------------------------
# loss: 0.137218  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.127889
#
# Epoch 70
# -------------------------------
# loss: 0.013565  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.128271
#
# Epoch 71
# -------------------------------
# loss: 0.003981  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.127316
#
# Epoch 72
# -------------------------------
# loss: 0.007075  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.126158
#
# Epoch 73
# -------------------------------
# loss: 0.026856  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.126336
#
# Epoch 74
# -------------------------------
# loss: 0.011608  [    8/  800]
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.128420
#
# Epoch 75
# -------------------------------
# loss: 0.010090  [    8/  800]
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.128001
#
# Epoch 76
# -------------------------------
# loss: 0.018973  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.126560
#
# Epoch 77
# -------------------------------
# loss: 0.009415  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.127238
#
# Epoch 78
# -------------------------------
# loss: 0.002764  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.127512
#
# Epoch 79
# -------------------------------
# loss: 0.008933  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.127199
#
# Epoch 80
# -------------------------------
# loss: 0.049106  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.127048
#
# Epoch 81
# -------------------------------
# loss: 0.007221  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.125891
#
# Epoch 82
# -------------------------------
# loss: 0.008577  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.127219
#
# Epoch 83
# -------------------------------
# loss: 0.075061  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.125368
#
# Epoch 84
# -------------------------------
# loss: 0.009174  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.124592
#
# Epoch 85
# -------------------------------
# loss: 0.004003  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.125880
#
# Epoch 86
# -------------------------------
# loss: 0.037460  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.126398
#
# Epoch 87
# -------------------------------
# loss: 0.004990  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.127172
#
# Epoch 88
# -------------------------------
# loss: 0.202636  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.126696
#
# Epoch 89
# -------------------------------
# loss: 0.016026  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.124311
#
# Epoch 90
# -------------------------------
# loss: 0.008961  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.125573
#
# Epoch 91
# -------------------------------
# loss: 0.008477  [    8/  800]
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.127731
#
# Epoch 92
# -------------------------------
# loss: 0.011792  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.124823
#
# Epoch 93
# -------------------------------
# loss: 0.006356  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.125249
#
# Epoch 94
# -------------------------------
# loss: 0.004416  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.124554
#
# Epoch 95
# -------------------------------
# loss: 0.006131  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.125957
#
# Epoch 96
# -------------------------------
# loss: 0.005403  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.125873
#
# Epoch 97
# -------------------------------
# loss: 0.013835  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.123163
#
# Epoch 98
# -------------------------------
# loss: 0.019779  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.124953
#
# Epoch 99
# -------------------------------
# loss: 0.110829  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.125037
#
# Epoch 100
# -------------------------------
# loss: 0.004273  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.124968
#
# Epoch 101
# -------------------------------
# loss: 0.014168  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.123348
#
# Epoch 102
# -------------------------------
# loss: 0.005153  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.124861
#
# Epoch 103
# -------------------------------
# loss: 0.003668  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.123903
#
# Epoch 104
# -------------------------------
# loss: 0.007033  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.124179
#
# Epoch 105
# -------------------------------
# loss: 0.071997  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.124896
#
# Epoch 106
# -------------------------------
# loss: 0.017377  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.123513
#
# Epoch 107
# -------------------------------
# loss: 0.005218  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.123631
#
# Epoch 108
# -------------------------------
# loss: 0.015615  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.124449
#
# Epoch 109
# -------------------------------
# loss: 0.079915  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.124973
#
# Epoch 110
# -------------------------------
# loss: 0.016243  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.125439
#
# Epoch 111
# -------------------------------
# loss: 0.003688  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.124484
#
# Epoch 112
# -------------------------------
# loss: 0.017399  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.122296
#
# Epoch 113
# -------------------------------
# loss: 0.125066  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.124821
#
# Epoch 114
# -------------------------------
# loss: 0.016231  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.123550
#
# Epoch 115
# -------------------------------
# loss: 0.020610  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.123076
#
# Epoch 116
# -------------------------------
# loss: 0.022254  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.122203
#
# Epoch 117
# -------------------------------
# loss: 0.016623  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.120496
#
# Epoch 118
# -------------------------------
# loss: 0.843663  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.122740
#
# Epoch 119
# -------------------------------
# loss: 0.011163  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.122036
#
# Epoch 120
# -------------------------------
# loss: 0.006664  [    8/  800]
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.121095
#
# Done!
# Training finished, took 41.05s

# %%
pos = 12
model.eval()
x, y = input_test_dataset[pos][0], input_test_dataset[pos][1]

print("accurracy: ",max_accurracy*100,"%")

#print(x,y)
with torch.no_grad():
    x = x.to(device)
    pred = best_model(x)
    print(pred)
    predicted, actual = pred.argmax(0), y
    print(f'Predicted: "{predicted}", Actual: "{actual}"')
# Out:
# accurracy:  96.5 %
# tensor([ 1.5414, -1.1198], device='mps:0')
# Predicted: "0", Actual: "0"
